# %%
# %run -i data_cleaning_operations.py

# %%
import csv
import pandas as pd
import glob

files = glob.glob('databcn\*.csv')
dfs = [pd.read_csv(f, encoding='utf-8') for f in files]
originaldata = pd.concat(dfs,ignore_index=True)
alldata = change_date_format_and_drop_duplicates(originaldata)
bcndata_clean_dataset = drop_duplicates_more_than_80_percent(alldata)
bcndata_clean_dataset.to_csv(r'clean_dataset\bcndata_clean_dataset.csv', encoding='utf-8')

# %%
files = glob.glob('datasagrada\*.csv')
dfs = [pd.read_csv(f, encoding='utf-8') for f in files]
originaldata = pd.concat(dfs,ignore_index=True)
alldata = change_date_format_and_drop_duplicates(originaldata)

# %%
sagrada_clean_dataset = drop_duplicates_more_than_80_percent(alldata)
sagrada_clean_dataset
# Out:
# <ipython-input-1-1ff1eefe9182>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataonemonth['temp'] = [difflib.SequenceMatcher(None, str(text1),str(text)).ratio() for text1 in dataonemonth['CONTENT'].tolist()]
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#                   USER                                            CONTENT  \
# ...

# %%
sagrada_clean_dataset.to_csv(r'clean_dataset\sagrada_clean_dataset.csv', encoding='utf-8')

# %%
files = glob.glob('datamila\*.csv')
dfs = [pd.read_csv(f, encoding='utf-8') for f in files]
originaldata = pd.concat(dfs,ignore_index=True)
alldata = change_date_format_and_drop_duplicates(originaldata)

# %%
mila_clean_dataset = drop_duplicates_more_than_80_percent(alldata)
mila_clean_dataset
# Out:
# <ipython-input-1-1ff1eefe9182>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataonemonth['temp'] = [difflib.SequenceMatcher(None, str(text1),str(text)).ratio() for text1 in dataonemonth['CONTENT'].tolist()]
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#                USER                                            CONTENT  \
# ...

# %%
files = glob.glob('dataparkguell\*.csv')
dfs = [pd.read_csv(f, encoding='utf-8') for f in files]
originaldata = pd.concat(dfs,ignore_index=True)
alldata = change_date_format_and_drop_duplicates(originaldata)

# %%
parkguell_clean_dataset = drop_duplicates_more_than_80_percent(alldata)
parkguell_clean_dataset
# Out:
# <ipython-input-1-1ff1eefe9182>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataonemonth['temp'] = [difflib.SequenceMatcher(None, str(text1),str(text)).ratio() for text1 in dataonemonth['CONTENT'].tolist()]
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#                USER                                            CONTENT  \
# ...

# %%
files = glob.glob('databatllo\*.csv')
dfs = [pd.read_csv(f, encoding='utf-8') for f in files]
originaldata = pd.concat(dfs,ignore_index=True)
alldata = change_date_format_and_drop_duplicates(originaldata)

# %%
batllo_clean_dataset = drop_duplicates_more_than_80_percent(alldata)
batllo_clean_dataset
# Out:
# <ipython-input-1-1ff1eefe9182>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataonemonth['temp'] = [difflib.SequenceMatcher(None, str(text1),str(text)).ratio() for text1 in dataonemonth['CONTENT'].tolist()]
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#                USER                                            CONTENT  \
# ...

# %%
mila_clean_dataset.to_csv(r'clean_dataset\mila_clean_dataset.csv', encoding='utf-8')
parkguell_clean_dataset.to_csv(r'clean_dataset\parkguell_clean_dataset.csv', encoding='utf-8')
batllo_clean_dataset.to_csv(r'clean_dataset\batllo_clean_dataset.csv', encoding='utf-8')
