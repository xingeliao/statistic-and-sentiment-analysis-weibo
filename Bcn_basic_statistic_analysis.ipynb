# %%
# %run -i basic_operations.py

# %%
bcndata_clean_dataset = pd.read_csv(r'clean_dataset\bcndata_clean_dataset.csv', encoding='utf-8',index_col=0)
bcndata_clean_dataset
# Out:
#                        USER  \
# 0            安徽农业大学青年志愿者联合会
# 1       SlumberLove西班牙旅拍工作室
# 4              只想静静的做个Mitao
# 5                       诺慎言
# 6                    我心中的天堂
# ...                     ...
# 27223                 清墨Mia
# 27226               星星仙女Mia
# 27227                  不正国乚
# 27228            YH-L热爱旅游生活
# 27229  URKALIAGROUP-西班牙移民房产
#
#                                                  CONTENT        DATE & TIME  \
# 0      #带你去旅游#奇特的建筑，一个以足球为灵魂的城市，西班牙巴塞罗那💃开放，自由，和谐，包容，豁...  2017年01月31日 22:44
# 1      崔宇&坦克五年爱情长跑，这是我们最长的一次旅行你的未来里有我，我的生命里不能没有你从巴塞罗那...  2017年01月31日 22:36
# 4      #带着微博去旅游##西班牙旅行# @走遍巴塞罗那 地中海的日出日落 云卷云舒 2西班牙·加的...  2017年01月30日 16:42
# 5      去西葡旅游买的网卡离开欧洲境内就失效了，在刚刚看旅游照片时才发现漏了几张没发上微博作为旅游记...  2017年01月30日 14:45
# 6      在瓦岱机场候机，由万象飞往琅勃拉邦，㊗我平安顺利。记得从巴塞罗那飞往罗马，在飞机落地的一刻，...  2017年01月30日 09:55
# ...                                                  ...                ...
# 27223                  巴塞罗那的斜阳。#不止旅行##带着微博去旅行##旅游vlog# ​  2020年12月01日 11:56
# ...

# %%
countyear, countmonth,countmonth2017to19, countyearmonth = count_post(bcndata_clean_dataset)
countyear
# Out:
# 2017    2464
# 2018    2492
# 2019    3159
# 2020    2281
# Name: YEAR, dtype: int64

# %%
# %matplotlib notebook
draw_countyear(countyear,title = 'Número de Post mencionado a "Barcelona" (2017-2020)',y_lim =3500)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
draw_countmonth(countmonth,title = 'Número de Post mencionado a "Barcelona" (Promedio de 4 años desde 2017 hasta 2020)',y_lim =400)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
draw_countmonth(countmonth2017to19,title = 'Número de Post mencionado a "Barcelona" (Promedio de 3 años desde 2017 hasta 2019)',y_lim =400)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
draw_countyearmonth(countyearmonth, title = 'Número de Post mencionado a "Barcelona" (cada mes desde 2017 hasta 2020)')
# Out:
# <img src="data:image/png;base64,..." width="640">
